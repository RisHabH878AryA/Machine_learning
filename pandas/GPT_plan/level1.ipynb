# %%
import pandas as pd

# %%
# 1] Load CSV, shape, columns, Read first 5 rows, Read last 5 rows
df = pd.read_csv("nba.csv")
df.head()
df.shape
df.columns
print(df['Team'].unique())
df.describe()
df.head(5)
df.tail(5)
# Out:
# ['Boston Celtics' 'Brooklyn Nets' 'New York Knicks' 'Philadelphia 76ers'
#  'Toronto Raptors' 'Golden State Warriors' 'Los Angeles Clippers'
#  'Los Angeles Lakers' 'Phoenix Suns' 'Sacramento Kings' 'Chicago Bulls'
#  'Cleveland Cavaliers' 'Detroit Pistons' 'Indiana Pacers'
#  'Milwaukee Bucks' 'Dallas Mavericks' 'Houston Rockets'
#  'Memphis Grizzlies' 'New Orleans Pelicans' 'San Antonio Spurs'
#  'Atlanta Hawks' 'Charlotte Hornets' 'Miami Heat' 'Orlando Magic'
#  'Washington Wizards' 'Denver Nuggets' 'Minnesota Timberwolves'
#  'Oklahoma City Thunder' 'Portland Trail Blazers' 'Utah Jazz' nan]
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# ...

# %%
# Column selection
df['Age']
df[['Name', 'Team']]
# df.Weight > 100
df[df['Weight'] > 200][['Name','Salary']]
# df[df['Salary'] > ]['Weight']
# Out:
#               Name      Salary
# 1      Jae Crowder   6796117.0
# 2     John Holland         NaN
# 4    Jonas Jerebko   5000000.0
# 5     Amir Johnson  12000000.0
# 6    Jordan Mickey   1170960.0
# ..             ...         ...
# 451  Chris Johnson    981348.0
# 452     Trey Lyles   2239800.0
# 453   Shelvin Mack   2433333.0
# 455   Tibor Pleiss   2900000.0
# 456    Jeff Withey    947276.0
#
# [335 rows x 2 columns]

# %%
# Boolean masking
mask1 = df['Age'] > 30
mask2 = df['Weight'] > 250

df[mask1 & mask2][['Name', 'Age', 'Weight']]
# Out:
#                   Name   Age  Weight
# 46         Elton Brand  37.0   254.0
# 78        Andrew Bogut  31.0   260.0
# 90    Anderson Varejao  33.0   273.0
# 119  Metta World Peace  36.0   260.0
# 167      Channing Frye  33.0   255.0
# 173         Sasha Kaun  31.0   260.0
# 237      Zaza Pachulia  32.0   275.0
# 265         Marc Gasol  31.0   255.0
# 271      Zach Randolph  34.0   260.0
# 292   Kendrick Perkins  31.0   270.0
# 330       Al Jefferson  31.0   289.0
# 413      Nick Collison  35.0   255.0
# 434        Chris Kaman  34.0   265.0

# %%
# Dropping columns
# df.drop('College')
# select rows where College is missing
df = df[~df['College'].isna()]
# df.drop('College', axis=1, inplace=True)
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Sorting
df = df.sort_values('Salary', ascending=False)
# df = df.sort_values(["Age", "Salary"])
df[df['Age'] > 31]
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 33     Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 339         Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# 349        Dwyane Wade              Miami Heat     3.0       SG  34.0    6-4
# 83      Andre Iguodala   Golden State Warriors     9.0       SF  32.0    6-6
# 271      Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 167      Channing Frye     Cleveland Cavaliers     9.0       PF  33.0   6-11
# 52         Carl Landry      Philadelphia 76ers     7.0       PF  32.0    6-9
# 19        Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 314        Kyle Korver           Atlanta Hawks    26.0       SG  35.0    6-7
# 93      Jamal Crawford    Los Angeles Clippers    11.0       SG  36.0    6-5
# 298         Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# ...
