# %%
import pandas as pd

# %% [markdown]
# Practicing dataframes

# %%
# dictionary of lists
df = pd.DataFrame({
    "name" : ["A", "B", "C", "D"],
    "age" : [5,34,4,34],
    "roll_no": [1000,1001,1002,1003]
})
print("describe: ", df.describe()) 

print("head: ", df.head())
print("shape: ", df.shape)
print("columns: ", df.columns)
print("info: ", df.info())
# Out:
# describe:               age      roll_no
# count   4.000000     4.000000
# mean   19.250000  1001.500000
# std    17.036725     1.290994
# min     4.000000  1000.000000
# 25%     4.750000  1000.750000
# 50%    19.500000  1001.500000
# 75%    34.000000  1002.250000
# max    34.000000  1003.000000
# head:    name  age  roll_no
# 0    A    5     1000
# 1    B   34     1001
# 2    C    4     1002
# 3    D   34     1003
# shape:  (4, 3)
# columns:  Index(['name', 'age', 'roll_no'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   age      4 non-null      int64
#  2   roll_no  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 292.0+ bytes
# info:  None
